# %%
act = input('輸入d或e加上數字')
txt = input('訊息')

act_type = act[0]
key = int(act[1::])
ntxt = ''

if act_type == 'd':
  for i in txt:
    nc = ord(i) - key
    ntxt += chr(nc)
else:
  for i in txt:
    nc = ord(i) + key
    ntxt += chr(nc)
print(ntxt)
# Out:
# 輸入d或e加上數字e6
# 訊息paodde
# vgujjk
