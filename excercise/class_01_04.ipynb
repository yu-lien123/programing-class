# %%
import random
bomb = random.randint(1,99)

lf = 0
rt = 100

while True:
  print(lf,'-',rt)
  gu = int(input())

  if gu <= lf or gu >= rt :
    print ('不要亂猜')
  elif gu > bomb :
    rt = gu
  elif gu < bomb :
    lf = gu
  else:
      print('猜中')
      break
# Out:
# 0 - 100
# 50
# 0 - 50
# 33
# 0 - 33
# 22
# 0 - 22
# 11
# 11 - 22
# 15
# 15 - 22
# 16
# 16 - 22
# 18
# 16 - 18
# 17
# 猜中
